# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# prompt: a notebook for in class notes

print("Hello, World!")
# In-class notes:

# Date: October 26, 2023
# Topic: Introduction to Python

# Key Concepts:
# - print() function: used to display output to the console
# - Strings: sequences of characters enclosed in quotes ("") or single quotes ('')
# - Comments: lines starting with '#' are ignored by the interpreter and used for documentation


# Example Code:

# This is a comment
# print("This will not be displayed")

# This line prints "Hello, World!" to the console.
print("Hello, World!")

# Variables:
name = "Alice" # Assigning the string "Alice" to the variable name
age = 30 # Assigning the integer 30 to the variable age

print(name) # Output: Alice
print(age) # Output: 30


# Data Types:
# - Integers (int): whole numbers (e.g., 10, -5, 0)
# - Floats (float): decimal numbers (e.g., 3.14, -2.5)
# - Strings (str): sequences of characters (e.g., "hello", 'Python')
# - Booleans (bool): True or False

# Operators:
# - Arithmetic operators (+, -, *, /, //, %, **)
# - Comparison operators (==, !=, >, <, >=, <=)
# - Logical operators (and, or, not)



# Additional Notes:

# ... (Add more notes as needed)

# Questions:

# ... (Add any questions you have)
# Out:
# Hello, World!
# Hello, World!
# Alice
# 30

# %% [markdown]
# # New Section

# %%
print("Hello")
print("Hello")
print("Hello")
print("Missing parenthesis")
print("Indentation error!")
# Out:
# Hello
# Hello
# Hello
# Missing parenthesis
# Indentation error!
